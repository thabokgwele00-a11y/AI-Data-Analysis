# %%
import pandas as pd

# This version ignores errors and handles messy formatting
try:
    df = pd.read_csv('/content/Top_10000_Movies.csv',
                    sep=None,             # Tells Pandas to guess the separator (comma, semicolon, etc.)
                    engine='python',      # Use the smarter parser
                    on_bad_lines='skip',  # Skip the broken rows
                    encoding='utf-8')     # Standard encoding
except:
    # If UTF-8 fails, try the older Latin encoding
    df = pd.read_csv('/content/Top_10000_Movies.csv',
                    sep=None,
                    engine='python',
                    on_bad_lines='skip',
                    encoding='latin1')

# Success check
print("Success! Data loaded.")
df.head()
# Out:
# Success! Data loaded.
#   Unnamed: 0        id original_language               original_title  \
# 0          0  580489.0                en  Venom: Let There Be Carnage
# 1          1  524434.0                en                     Eternals
# 2          2  438631.0                en                         Dune
# 3          3  796499.0                en              Army of Thieves
# 4          4  550988.0                en                     Free Guy
#
#    popularity release_date  vote_average  vote_count  \
# 0    5401.308   2021-09-30           6.8      1736.0
# 1    3365.535   2021-11-03           7.1       622.0
# 2    2911.423   2021-09-15           8.0      3632.0
# 3    2552.437   2021-10-27           6.9       555.0
# 4    1850.470   2021-08-11           7.8      3493.0
#
#                                                genre  \
# 0         ['Science Fiction', 'Action', 'Adventure']
# 1  ['Action', 'Adventure', 'Science Fiction', 'Fa...
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0        id original_language   original_title  popularity  \
# 10009       9995     530.0                en  A Grand Day Out       9.266
# 10010       9996   15934.0                en      El cantante      10.417
# 10011       9997  162215.0                en   How I Live Now       9.520
# 10012       9998    5723.0                en             Once       9.267
# 10013       9999  311667.0                en  Manhattan Night       9.273
#
#       release_date  vote_average  vote_count  \
# 10009   1990-05-18           7.5       594.0
# 10010   2006-09-12           7.0        80.0
# 10011   2013-09-10           6.6       705.0
# 10012   2007-03-23           7.4       990.0
# 10013   2016-05-20           6.0       304.0
#
#                                                    genre  \
# 10009  ['Adventure', 'Animation', 'Comedy', 'Science ...
# 10010                      ['History', 'Drama', 'Music']
# 10011             ['Drama', 'Action', 'Thriller', 'War']
# ...

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'id', 'original_language', 'original_title', 'popularity',
#        'release_date', 'vote_average', 'vote_count', 'genre', 'overview',
#        'revenue', 'runtime', 'tagline'],
#       dtype='object')

# %%
df.sort_values(by = 'revenue', ascending = True).head(5)
# Out:
#      Unnamed: 0        id original_language  \
# 4194       4180  624620.0                en
# 7802       7788   15058.0                en
# 7804       7790   13706.0                en
# 7806       7792  492621.0                en
# 7809       7795  337960.0                en
#
#                                original_title  popularity release_date  \
# 4194         Paw Patrol: Ready, Race, Rescue!      21.595   2019-08-02
# 7802                                    Speak      11.072   2004-01-20
# 7804  Winnie the Pooh: A Very Merry Pooh Year      13.572   2002-01-01
# 7806                         The Midnight Man      15.079   2016-09-30
# 7809                          Holding the Man       9.827   2015-08-27
#
#       vote_average  vote_count                    genre  \
# 4194           6.9        88.0  ['Animation', 'Family']
# 7802           6.8       331.0                ['Drama']
# 7804           6.8       128.0  ['Animation', 'Family']
# ...

# %%
df.sort_values(by = 'revenue', ascending = False).head(5)
# Out:
#      Unnamed: 0        id original_language                original_title  \
# 66           66   19995.0                en                        Avatar
# 167         167  299534.0                en             Avengers: Endgame
# 489         489     597.0                en                       Titanic
# 1013       1013  140607.0                en  Star Wars: The Force Awakens
# 97           97  299536.0                en        Avengers: Infinity War
#
#       popularity release_date  vote_average  vote_count  \
# 66       374.059   2009-12-10           7.5     24280.0
# 167      193.860   2019-04-24           8.3     19434.0
# 489       94.235   1997-11-18           7.9     19999.0
# 1013      59.007   2015-12-15           7.3     16314.0
# 97       307.188   2018-04-25           8.3     23027.0
#
#                                                   genre  \
# 66    ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 167          ['Adventure', 'Science Fiction', 'Action']
# ...

# %% [markdown]
# Insight: The highest grossing movie in this dataset is Avatar. Some movies have 0 revenue listed, indicating missing data that needs cleaning.
